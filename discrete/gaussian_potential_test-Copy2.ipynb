# %%
# in case there are any problems with importing because path is wrong
import sys
sys.path.append('/Users/daniel/Princeton Dropbox/Daniel Gurevich/Research/discrete_sr/code/SPIDER_discrete')

# %%
import numpy as np

from commons.weight import *
from commons.utils import save, load
from library import *
from process_library_terms import *
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
#positions, vs, deltat, dims = load('Matt/sim_n64_v03.npy', 4)
#positions, vs, deltat, dims = load('Matt/sim_n1024.npy', 4)
#positions, vs, deltat, dims = load('Matt/sim_n1024_default_v2.npy', 4)
positions, vs, deltat, dims = load('Matt/sim_n10000.npy', 4)

#Lsf = 100 # length scaling factor - to nondimensionalize rho
#Tsf = 0.01 # time scaling factor - to keep v~O(1)
#positions *= Lsf
#vs *= (Lsf*Tsf)
#deltat /= Tsf
#dims[:-1] *= Lsf

print(positions.shape, vs.shape, deltat, dims)

Np, nt = positions.shape[0], positions.shape[2]
world_size = np.array([dims[0], dims[0], dims[1]])
print(world_size)
# Out:
# (10000, 2, 512) (10000, 2, 512) 0.00125 [  1 512]
# [  1   1 512]

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
plt.rcParams['animation.ffmpeg_path'] = '/Users/daniel/Documents/ffmpeg-7.1/ffmpeg'

# vid_file = 'Matt/sim_n10000.mp4'

# fig, ax = plt.subplots(figsize=(6, 6))
# qv = ax.quiver(positions[:, 0, -1], positions[:, 1, -1], 1, 0, clim=[-np.pi, np.pi], cmap='hsv')
# fig.colorbar(qv)

# def animate(i):
#     if i % 10 == 0:
#         print(i)
#     qv.set_offsets(positions[:, :, i])
#     norms = np.sqrt(vs[:, 0, i] ** 2 + vs[:, 1, i] ** 2)
#     qv.set_UVC(vs[:, 0, i] / norms, vs[:, 1, i] / norms, np.angle(vs[:, 0, i] + 1.0j * vs[:, 1, i]))
#     return qv,

# anim = FuncAnimation(fig, animate, np.arange(0, positions.shape[-1]), interval=1, blit=True)
# FFwriter = animation.FFMpegWriter(fps=24, codec="libx264")
# anim.save(vid_file, writer=FFwriter, dpi=100)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(figsize=(6, 6))
qv = ax.quiver(positions[:, 0, -1], positions[:, 1, -1], 1, 0, clim=[-np.pi, np.pi], cmap='hsv')

def animate(i):
    if i % 10 == 0:
        print(i)
    qv.set_offsets(positions[:, :, i])
    norms = np.sqrt(vs[:, 0, i] ** 2 + vs[:, 1, i] ** 2)
    qv.set_UVC(vs[:, 0, i] / norms, vs[:, 1, i] / norms, np.angle(vs[:, 0, i] + 1.0j * vs[:, 1, i]))
    return qv,

t=480
animate(t)
plt.xlabel("$x$")
plt.ylabel("$y$")

the_divider = make_axes_locatable(ax)
color_axis = the_divider.append_axes("right", size="5%", pad=0.1)
cbar = fig.colorbar(qv, cax=color_axis)

name = f'quiver_{t}.png'
plt.savefig(name, dpi=600, bbox_inches='tight')
plt.show()
# Out:
# 480

# %%
# %%prun # profiling

data_dict = {}
data_dict['v'] = vs
v_obs = Observable(string='v', rank=1)
observables = [v_obs]

# fix random seed
np.random.seed(1)

# initial setup of dataset
corr_L = 0.02 #0.2
#corr_T = 0.01 #0.1
kernel_sigma = 0.02 # 0.05
cg_res = 256
srd = SRDataset(world_size=world_size, data_dict=data_dict, particle_pos=positions, observables=observables, rho_scale=Np,
                irreps=SRDataset.all_rank2_irreps(), kernel_sigma=kernel_sigma, cg_res=cg_res, deltat=deltat, cutoff=6)
v_est = np.mean(np.abs(vs))*2**0.5
print(v_est)

# initialize libraries, domains, and weights
#srd.make_libraries(max_complexity=4, max_rho=2)
srd.make_libraries(max_complexity=5, max_rho=2)
#srd.make_libraries(max_complexity=6, max_rho=2)
for irrep in srd.irreps:
    print(irrep, ":", len(srd.libs[irrep].terms))

dom_width = 0.1 # 0.3
dom_time = 40
#srd.make_domains(ndomains=10, domain_size=[dom_width, dom_width, dom_time], pad=kernel_sigma*4) #*8
srd.make_domains(ndomains=30, domain_size=[dom_width, dom_width, dom_time], pad=kernel_sigma*4) #*8
srd.make_weights(m=8, qmax=1)
srd.set_LT_scale(L=corr_L, T=corr_L/v_est) # note that this line must go before make_library_matrices
#srd.set_LT_scale(L=corr_L, T=corr_T) # note that this line must go before make_library_matrices
srd.make_library_matrices(debug=False)

save('Q_gauss1024.npy', srd)
# Out:
# 0.8486350690926066
# Rank 0 : 41
# Rank 1 : 50
# Antisymmetric rank 2 : 14
# Symmetric trace-free rank 2 : 33
#          109882882 function calls (104667085 primitive calls) in 355.940 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4260  247.986    0.058  248.002    0.058 coarse_grain_utils.py:267(poly_coarse_grain_time_slices)
#      4260   28.071    0.007  289.750    0.068 process_library_terms.py:92(eval_prime)
#       355   12.631    0.036   12.661    0.036 {built-in method time.sleep}
#    624960   10.852    0.000   11.214    0.000 polynomial.py:672(polyval)
#    624960    4.600    0.000    6.636    0.000 _function_base_impl.py:5078(trapezoid)
#    208320    3.070    0.000  296.379    0.001 process_library_terms.py:400(eval_term)
#    457920    2.851    0.000    7.805    0.000 arrayprint.py:966(fillFormat)
#   1573879    2.567    0.000    2.567    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    624960    2.562    0.000    3.660    0.000 function_base.py:25(linspace)
# 2333760/457920    2.308    0.000    5.481    0.000 arrayprint.py:815(recurser)
#     18180    2.111    0.000    2.123    0.000 diff.py:479(_apply_to_array)
#    208320    1.762    0.000  501.322    0.002 process_library_terms.py:378(eval_on_domain)
#    244800    1.520    0.000    2.141    0.000 numeric.py:978(tensordot)
#    648630    1.232    0.000    1.232    0.000 {method 'astype' of 'numpy.ndarray' objects}
#    208320    1.122    0.000   82.425    0.000 process_library_terms.py:58(get_weight_array)
#    624960    0.964    0.000   17.465    0.000 _polybase.py:937(linspace)
# 19600270/19600269    0.962    0.000    0.962    0.000 {built-in method builtins.len}
#   1395840    0.949    0.000    1.234    0.000 arrayprint.py:1052(__call__)
#      81/1    0.827    0.010    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#    624960    0.821    0.000    1.282    0.000 polyutils.py:286(mapdomain)
#    457920    0.795    0.000   16.127    0.000 arrayprint.py:544(_array2string)
#    522720    0.782    0.000    0.782    0.000 process_library_terms.py:82(__repr__)
# 5006973/2393132    0.742    0.000    1.226    0.000 {built-in method builtins.hash}
#    208320    0.680    0.000    0.770    0.000 numeric.py:143(ones)
#    624960    0.680    0.000    0.680    0.000 {built-in method _warnings.warn}
#    457920    0.671    0.000    9.620    0.000 arrayprint.py:473(_get_format_function)
#      4260    0.609    0.000    0.610    0.000 numeric.py:218(ones_like)
#   1857416    0.572    0.000    1.115    0.000 {built-in method builtins.max}
#    930481    0.566    0.000    1.507    0.000 fromnumeric.py:69(_wrapreduction)
#    457920    0.560    0.000   18.404    0.000 arrayprint.py:582(array2string)
#   1395840    0.552    0.000    1.470    0.000 arrayprint.py:779(_extendLine_pretty)
#   2791680    0.540    0.000    0.540    0.000 {built-in method numpy._core._multiarray_umath.dragon4_positional}
#   1853760    0.529    0.000    0.784    0.000 arrayprint.py:1016(<genexpr>)
#    457920    0.521    0.000    0.887    0.000 arrayprint.py:64(_make_options_dict)
#    457920    0.499    0.000   19.784    0.000 process_library_terms.py:170(__repr__)
#   1395840    0.493    0.000    0.694    0.000 arrayprint.py:765(_extendLine)
#    457920    0.473    0.000   16.801    0.000 arrayprint.py:527(wrapper)
#   1997164    0.472    0.000    0.472    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#   1853760    0.468    0.000    1.423    0.000 arrayprint.py:1021(<genexpr>)
#    624960    0.445    0.000    7.810    0.000 _function_base_impl.py:5211(trapz)
#    634176    0.413    0.000    0.413    0.000 polyutils.py:239(mapparms)
# 4514330/4514312    0.402    0.000    0.550    0.000 {built-in method builtins.isinstance}
#    457920    0.387    0.000    8.285    0.000 arrayprint.py:939(__init__)
# 624960/208320    0.361    0.000    8.213    0.000 process_library_terms.py:516(int_arr)
#   1160670    0.320    0.000    0.409    0.000 process_library_terms.py:25(__hash__)
#    457922    0.318    0.000    0.318    0.000 {built-in method builtins.locals}
#    457920    0.313    0.000    0.313    0.000 arrayprint.py:423(_get_formatdict)
#   1260112    0.298    0.000    0.298    0.000 {built-in method numpy.array}
#    624960    0.294    0.000   12.790    0.000 _polybase.py:525(__call__)
#    633544    0.256    0.000    0.256    0.000 {built-in method numpy.arange}
#    193536    0.236    0.000    0.800    0.000 polyutils.py:66(as_series)
#     18180    0.234    0.000    0.419    0.000 _linalg.py:318(solve)
#    476100    0.229    0.000    0.418    0.000 _ufunc_config.py:410(__enter__)
#      81/1    0.228    0.003    0.000    0.000 selectors.py:558(select)
#    457920    0.211    0.000    8.497    0.000 arrayprint.py:432(<lambda>)
#   1853760    0.211    0.000    0.281    0.000 arrayprint.py:1025(<genexpr>)
#     18180    0.200    0.000    0.241    0.000 coefs.py:260(_calc_accuracy)
#         1    0.200    0.200    0.200    0.200 {built-in method _pickle.dump}
#    857204    0.192    0.000    0.302    0.000 z3base.py:124(__eq__)
#    457920    0.191    0.000   18.596    0.000 arrayprint.py:1652(_array_str_implementation)
#    457920    0.190    0.000    1.000    0.000 fromnumeric.py:2781(max)
#   1853760    0.190    0.000    0.247    0.000 arrayprint.py:1026(<genexpr>)
#    109180    0.182    0.000    0.318    0.000 dataclasses.py:1540(replace)
#    624960    0.181    0.000    1.989    0.000 {method 'sum' of 'numpy.ndarray' objects}
#    105536    0.176    0.000    0.177    0.000 {built-in method numpy.zeros}
#    244800    0.176    0.000    2.337    0.000 process_library_terms.py:64(<lambda>)
#   2346532    0.174    0.000    0.174    0.000 {built-in method builtins.issubclass}
#    979200    0.174    0.000    0.212    0.000 {built-in method math.prod}
#   1395840    0.171    0.000    0.171    0.000 {method 'split' of 'str' objects}
#    457920    0.169    0.000    5.649    0.000 arrayprint.py:806(_formatArray)
#        82    0.168    0.002  306.338    3.736 base_events.py:1909(_run_once)
#    457920    0.165    0.000    0.811    0.000 fromnumeric.py:2925(min)
#      6060    0.161    0.000    3.483    0.001 diff.py:278(diff)
# 587525/522725    0.161    0.000   20.046    0.000 {built-in method builtins.repr}
#   1395840    0.149    0.000    0.149    0.000 {method 'splitlines' of 'str' objects}
#    193536    0.149    0.000    0.265    0.000 _type_check_impl.py:646(common_type)
#   1428741    0.138    0.000    0.138    0.000 {method 'items' of 'dict' objects}
#    457920    0.131    0.000   20.088    0.000 process_library_terms.py:173(__hash__)
#    624960    0.118    0.000    1.808    0.000 _methods.py:50(_sum)
#    638310    0.116    0.000    0.533    0.000 <string>:2(__hash__)
#       245    0.114    0.000    0.115    0.000 z3core.py:4275(Z3_solver_check_assumptions)
# 155322/38350    0.114    0.000    0.140    0.000 z3base.py:187(all_indices)
#    624960    0.111    0.000    0.111    0.000 {method 'result_type' of 'numpy._core._multiarray_umath._array_converter' objects}
#   1258477    0.104    0.000    0.104    0.000 {built-in method numpy.asanyarray}
#    624960    0.103    0.000    0.103    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#    476100    0.102    0.000    0.194    0.000 _ufunc_config.py:426(__exit__)
#    624960    0.100    0.000    0.142    0.000 numeric.py:1918(isscalar)
#    476102    0.099    0.000    0.099    0.000 {method 'set' of '_contextvars.ContextVar' objects}
#    937920    0.099    0.000    0.099    0.000 {method 'rstrip' of 'str' objects}
#      4260    0.097    0.000    0.160    0.000 _index_tricks_impl.py:147(__getitem__)
#    387264    0.097    0.000    0.184    0.000 {built-in method builtins.any}
#      6060    0.097    0.000    0.103    0.000 numeric.py:65(zeros_like)
#    496564    0.097    0.000    0.097    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     18180    0.096    0.000    0.197    0.000 coefs.py:228(_build_matrix)
#    476102    0.092    0.000    0.092    0.000 {method 'reset' of '_contextvars.ContextVar' objects}
#         4    0.089    0.022   95.479   23.870 process_library_terms.py:440(make_Q)
#    476100    0.087    0.000    0.087    0.000 {built-in method numpy._core._multiarray_umath._make_extobj}
#    304347    0.084    0.000    0.095    0.000 {built-in method _abc._abc_instancecheck}
#    983881    0.082    0.000    0.082    0.000 {built-in method numpy.asarray}
#    624960    0.080    0.000    0.080    0.000 {method 'as_arrays' of 'numpy._core._multiarray_umath._array_converter' objects}
#    217492    0.077    0.000    0.077    0.000 {built-in method numpy.empty}
#    122400    0.075    0.000    2.412    0.000 {built-in method _functools.reduce}
#    133920    0.073    0.000    0.073    0.000 diff.py:497(_shift_slice)
#    624960    0.066    0.000    0.066    0.000 fromnumeric.py:3267(ndim)
#    464312    0.065    0.000    0.065    0.000 {function Counter.update at 0x104a3fb00}
#     18180    0.063    0.000    0.971    0.000 coefs.py:142(calc_coefs)
#    476100    0.062    0.000    0.062    0.000 _ufunc_config.py:400(__init__)
#    458330    0.062    0.000    0.062    0.000 {method 'copy' of 'dict' objects}
#    244804    0.061    0.000    0.061    0.000 {built-in method builtins.iter}
#     73728    0.059    0.000    0.128    0.000 numeric.py:782(convolve)
#    304347    0.059    0.000    0.154    0.000 abc.py:117(__instancecheck__)
#     64512    0.058    0.000    0.642    0.000 _polybase.py:305(__init__)
#    457920    0.058    0.000    0.058    0.000 {method 'discard' of 'set' objects}
#    457922    0.058    0.000    0.058    0.000 {method 'add' of 'set' objects}
#    405504    0.057    0.000    0.057    0.000 polyutils.py:125(<genexpr>)
#    657312    0.053    0.000    0.053    0.000 {built-in method _operator.index}
#    624960    0.050    0.000    0.050    0.000 function_base.py:20(_linspace_dispatcher)
#    624960    0.050    0.000    0.050    0.000 _function_base_impl.py:5074(_trapezoid_dispatcher)
#    523888    0.049    0.000    0.049    0.000 {built-in method builtins.getattr}
#    457920    0.049    0.000    0.049    0.000 arrayprint.py:930(_none_or_positive_arg)
#     39094    0.049    0.000    0.160    0.000 __init__.py:595(__init__)
#    624960    0.047    0.000    0.047    0.000 fromnumeric.py:3263(_ndim_dispatcher)
#         1    0.045    0.045    0.045    0.045 {built-in method _io.open}
#    458689    0.043    0.000    0.043    0.000 {built-in method builtins.id}
#     73728    0.042    0.000    0.042    0.000 {built-in method numpy._core._multiarray_umath.correlate}
#      6060    0.041    0.000    1.019    0.000 coefs.py:19(coefficients)
#    457920    0.041    0.000    0.041    0.000 {built-in method _thread.get_ident}
#         2    0.036    0.018    0.042    0.021 _methods.py:144(_var)
#    457920    0.036    0.000    0.036    0.000 fromnumeric.py:2776(_max_dispatcher)
#    457920    0.036    0.000    0.036    0.000 fromnumeric.py:2920(_min_dispatcher)
#     33944    0.035    0.000    0.846    0.000 process_library_terms.py:550(int_by_parts_dim)
#    319913    0.034    0.000    0.034    0.000 {method 'keys' of 'dict' objects}
#    211968    0.034    0.000    0.048    0.000 _type_check_impl.py:265(iscomplexobj)
#      3900    0.034    0.000    3.668    0.001 process_library_terms.py:616(diff)
#     18180    0.034    0.000    0.068    0.000 _linalg.py:148(_commonType)
#      4260    0.032    0.000    0.053    0.000 numeric.py:1736(indices)
# 40136/13320    0.032    0.000    0.878    0.000 process_library_terms.py:526(int_by_parts)
#         1    0.031    0.031    0.031    0.031 {method 'disable' of '_lsprof.Profiler' objects}
#      9216    0.031    0.000    0.077    0.000 polynomial.py:471(polyder)
#      9216    0.030    0.000    0.184    0.000 polyutils.py:666(_pow)
#    125099    0.030    0.000    0.034    0.000 z3core.py:1563(Check)
#    405504    0.030    0.000    0.030    0.000 polyutils.py:120(<genexpr>)
#      4260    0.029    0.000    0.045    0.000 shape_base.py:219(vstack)
#      6060    0.028    0.000    3.517    0.001 diff.py:249(apply)
# 84419/18520    0.027    0.000    0.372    0.000 z3base.py:205(mapper)
#     18432    0.027    0.000    0.084    0.000 _polybase.py:267(_get_coefficients)
#    271079    0.027    0.000    0.027    0.000 {method 'get' of 'dict' objects}
#      3900    0.027    0.000    0.072    0.000 operators.py:125(_eval_args)
#       696    0.025    0.000    0.026    0.000 z3core.py:4161(Z3_solver_assert)
#     57144    0.025    0.000    0.045    0.000 z3core.py:2860(Z3_sort_to_ast)
#         1    0.025    0.025  357.336  357.336 {built-in method builtins.exec}
#     32702    0.025    0.000    0.041    0.000 {built-in method _collections._count_elements}
#     39094    0.025    0.000    0.111    0.000 __init__.py:669(update)
#     27340    0.024    0.000    0.158    0.000 library.py:270(get_spatial_orders)
#    192947    0.024    0.000    0.024    0.000 {method 'append' of 'list' objects}
#    109080    0.023    0.000    0.034    0.000 coefs.py:267(<lambda>)
#    244800    0.023    0.000    0.023    0.000 multiarray.py:750(dot)
#      9216    0.022    0.000    0.088    0.000 polynomial.py:374(polydiv)
# 31954/21815    0.022    0.000    0.086    0.000 functools.py:977(__get__)
#    243000    0.022    0.000    0.022    0.000 {built-in method builtins.abs}
#    109180    0.021    0.000    0.032    0.000 dataclasses.py:1296(_is_dataclass_instance)
#    218640    0.021    0.000    0.021    0.000 multiarray.py:1089(copyto)
#    244800    0.020    0.000    0.020    0.000 numeric.py:974(_tensordot_dispatcher)
#    244800    0.020    0.000    0.020    0.000 numeric.py:1152(<genexpr>)
#       476    0.020    0.000    0.023    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#    244800    0.019    0.000    0.019    0.000 numeric.py:1158(<genexpr>)
#      5944    0.019    0.000    0.487    0.000 library.py:157(ES_prod)
#     36360    0.018    0.000    0.029    0.000 _linalg.py:123(_makearray)
#      9216    0.018    0.000    1.369    0.000 weight.py:18(weight_1d)
#     64800    0.018    0.000    0.161    0.000 process_library_terms.py:146(__hash__)
#         1    0.017    0.017    0.039    0.039 __init__.py:280(_compile)
#     17784    0.017    0.000    0.140    0.000 library.py:38(map)
#     18638    0.017    0.000    0.380    0.000 library.py:544(map)
#      4260    0.016    0.000    0.016    0.000 serialize.py:30(_numba_unpickle)
#    124223    0.016    0.000    0.016    0.000 {built-in method builtins.hasattr}
#      8144    0.016    0.000    0.265    0.000 process_library_terms.py:362(get_index_assignments)
#     64512    0.016    0.000    0.020    0.000 polyutils.py:37(trimseq)
#      9216    0.016    0.000    0.327    0.000 _polybase.py:592(__divmod__)
#     17784    0.015    0.000    0.090    0.000 library.py:293(map)
#     42173    0.015    0.000    0.031    0.000 {built-in method builtins.sorted}
#     16688    0.015    0.000    0.088    0.000 library.py:461(derivs_along)
#      8235    0.015    0.000    0.071    0.000 library.py:45(eq_canon)
#      9216    0.014    0.000    0.077    0.000 legendre.py:148(leg2poly)
#     57144    0.014    0.000    0.067    0.000 z3.py:562(as_ast)
#     18180    0.013    0.000    0.031    0.000 coefs.py:240(_build_rhs)
#     13920    0.013    0.000    0.017    0.000 numeric.py:1373(normalize_axis_tuple)
#     36360    0.013    0.000    0.019    0.000 _linalg.py:142(_realType)
#    211968    0.013    0.000    0.013    0.000 _type_check_impl.py:168(_is_type_dispatcher)
#      6960    0.013    0.000    0.035    0.000 numeric.py:1437(moveaxis)
#     18432    0.012    0.000    0.034    0.000 fromnumeric.py:89(_wrapreduction_any_all)
#      4260    0.012    0.000    0.016    0.000 shape_base.py:81(atleast_2d)
#      3900    0.012    0.000    3.549    0.001 operators.py:81(apply)
#     24562    0.012    0.000    0.047    0.000 z3.py:350(__del__)
#     23080    0.012    0.000    0.015    0.000 library.py:200(parse_ind)
#     17784    0.012    0.000    0.305    0.000 library.py:440(map)
#     24562    0.012    0.000    0.056    0.000 z3.py:345(__init__)
#      9216    0.012    0.000    0.134    0.000 weight.py:4(weight_leg)
#     24562    0.012    0.000    0.020    0.000 z3core.py:1633(Z3_inc_ref)
#      6405    0.011    0.000    0.138    0.000 library.py:567(eq_canon)
#      6392    0.011    0.000    0.059    0.000 library.py:192(set_order_counts)
#    110241    0.011    0.000    0.011    0.000 {method 'values' of 'dict' objects}
#         1    0.011    0.011   30.399   30.399 process_library_terms.py:487(make_library_matrices)
#     54541    0.011    0.000    0.016    0.000 _linalg.py:128(isComplexType)
#    193536    0.011    0.000    0.011    0.000 _type_check_impl.py:642(_common_type_dispatcher)
#     87199    0.011    0.000    0.014    0.000 z3.py:400(ctx_ref)
#      5362    0.011    0.000    0.028    0.000 z3base.py:138(index_rank)
# 2160/1920    0.011    0.000    2.247    0.001 diff.py:155(apply)
#       138    0.010    0.000    0.012    0.000 process_library_terms.py:240(get_char_size)
# 30159/8153    0.010    0.000    0.010    0.000 process_library_terms.py:273(lists_for_N)
#     13198    0.010    0.000    0.071    0.000 library.py:341(map)
#      9216    0.010    0.000    0.299    0.000 _polybase.py:561(__mul__)
#     11768    0.010    0.000    0.074    0.000 library.py:145(cast_to_term)
#     64800    0.010    0.000    0.125    0.000 process_library_terms.py:143(__repr__)
#    275005    0.009    0.000    0.009    0.000 z3types.py:24(from_param)
#      9216    0.009    0.000    0.206    0.000 _polybase.py:900(deriv)
#     23080    0.009    0.000    0.073    0.000 library.py:273(get_all_orders)
#     24562    0.009    0.000    0.011    0.000 z3core.py:1637(Z3_dec_ref)
#     14641    0.009    0.000    0.061    0.000 fromnumeric.py:3068(prod)
#       118    0.009    0.000    0.009    0.000 z3core.py:4137(Z3_solver_dec_ref)
#     10750    0.009    0.000    0.049    0.000 z3.py:404(eq)
#      9216    0.009    0.000    0.314    0.000 _polybase.py:604(__pow__)
#     18180    0.008    0.000    0.008    0.000 _linalg.py:198(_assert_stacked_square)
#      8235    0.008    0.000    0.094    0.000 library.py:453(eq_canon)
#     18432    0.008    0.000    0.042    0.000 fromnumeric.py:2513(all)
#      5824    0.008    0.000    0.086    0.000 library.py:484(antidiff)
#      9216    0.008    0.000    0.099    0.000 polynomial.py:336(polymul)
#      3072    0.008    0.000    1.377    0.000 process_library_terms.py:54(make_weight_objs)
# 12180/12135    0.008    0.000    0.008    0.000 {built-in method _abc._abc_subclasscheck}
#      9216    0.008    0.000    0.367    0.000 weight.py:13(weight_poly)
#     30982    0.008    0.000    0.084    0.000 library.py:43(<genexpr>)
#     18180    0.007    0.000    0.007    0.000 {built-in method builtins.round}
#     24352    0.007    0.000    0.028    0.000 library.py:576(max_prime_derivatives)
#     64512    0.007    0.000    0.007    0.000 {method 'isidentifier' of 'str' objects}
#      6060    0.007    0.000    0.032    0.000 diff.py:238(__init__)
#     15242    0.007    0.000    0.012    0.000 z3core.py:3105(Z3_get_sort)
#         1    0.007    0.007    0.007    0.007 process_library_terms.py:30(__post_init__)
#     36422    0.007    0.000    0.318    0.000 library.py:549(<genexpr>)
#    173755    0.007    0.000    0.007    0.000 z3.py:218(ref)
#     40256    0.007    0.000    0.007    0.000 library.py:337(own_indices)
#     84/81    0.007    0.000    0.013    0.000 events.py:86(_run)
#     63864    0.007    0.000    0.011    0.000 library.py:577(<genexpr>)
#     16608    0.006    0.000    0.011    0.000 process_library_terms.py:372(<lambda>)
#      3900    0.006    0.000    3.555    0.001 operators.py:78(__call__)
#      9216    0.006    0.000    0.344    0.000 _polybase.py:569(__truediv__)
#     18180    0.006    0.000    0.006    0.000 _linalg.py:192(_assert_stacked_2d)
#     18520    0.006    0.000    0.378    0.000 z3base.py:204(map_all_indices)
#      6392    0.006    0.000    0.008    0.000 __init__.py:634(elements)
#     73728    0.006    0.000    0.006    0.000 numeric.py:778(_convolve_dispatcher)
#      5944    0.006    0.000    0.180    0.000 library.py:38(canonicalize)
#      8235    0.006    0.000    0.011    0.000 library.py:300(eq_canon)
#     10750    0.006    0.000    0.010    0.000 z3core.py:3090(Z3_is_eq_ast)
#      6944    0.006    0.000    0.006    0.000 <string>:2(__eq__)
#         2    0.005    0.003    0.050    0.025 utils.py:7(<genexpr>)
#      5376    0.005    0.000    0.050    0.000 library.py:579(diff)
#     51399    0.005    0.000    0.005    0.000 library.py:290(own_indices)
#     12065    0.005    0.000    0.015    0.000 library.py:457(nderivs)
#      9156    0.005    0.000    0.038    0.000 z3.py:2433(sort)
#     64920    0.005    0.000    0.005    0.000 _polybase.py:111(symbol)
#      3900    0.005    0.000    0.076    0.000 operators.py:73(__init__)
#      1980    0.005    0.000    1.286    0.001 diff.py:216(__call__)
#      2160    0.004    0.000    0.005    0.000 diff.py:133(__init__)
#      6272    0.004    0.000    0.022    0.000 library.py:572(drop)
#         1    0.004    0.004    0.004    0.004 z3core.py:1626(Z3_mk_context_rc)
#      9216    0.004    0.000    0.189    0.000 polynomial.py:432(polypow)
#         1    0.004    0.004    0.004    0.004 _shape_base_impl.py:669(dstack)
#        21    0.004    0.000    0.007    0.000 enum.py:1562(__and__)
#     11768    0.004    0.000    0.155    0.000 library.py:35(inc_inds)
#      5237    0.004    0.000    0.007    0.000 library.py:348(eq_canon)
#      2887    0.004    0.000    0.111    0.000 z3.py:1220(_coerce_exprs)
#      3414    0.004    0.000    0.011    0.000 library.py:408(__lt__)
#      4928    0.004    0.000    0.408    0.000 library.py:447(__mul__)
#     13575    0.004    0.000    0.012    0.000 z3base.py:145(highest_index)
#     33239    0.004    0.000    0.004    0.000 library.py:434(sub_exprs)
#         1    0.004    0.004    0.107    0.107 process_library_terms.py:207(find_scales)
#      6376    0.004    0.000    0.004    0.000 process_library_terms.py:127(__getitem__)
#      4407    0.004    0.000    0.004    0.000 {built-in method builtins.sum}
# 94292/94234    0.004    0.000    0.004    0.000 z3types.py:64(from_param)
#     18432    0.004    0.000    0.005    0.000 polyutils.py:699(_as_int)
#      5824    0.004    0.000    0.032    0.000 process_library_terms.py:66(increment)
#     19940    0.004    0.000    0.005    0.000 z3base.py:147(<genexpr>)
#      5774    0.004    0.000    0.060    0.000 z3.py:2376(cast)
#     18180    0.004    0.000    0.004    0.000 {built-in method math.factorial}
#      5362    0.004    0.000    0.052    0.000 library.py:402(rank)
#     18180    0.004    0.000    0.004    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#      9216    0.004    0.000    0.331    0.000 _polybase.py:580(__floordiv__)
#       127    0.003    0.000    0.004    0.000 z3core.py:4295(Z3_solver_get_model)
#      4260    0.003    0.000    0.008    0.000 shape_base.py:215(_vhstack_dispatcher)
#      9221    0.003    0.000    0.005    0.000 <frozen importlib._bootstrap>:645(parent)
#     11336    0.003    0.000    0.004    0.000 process_library_terms.py:48(__post_init__)
#      1920    0.003    0.000    2.250    0.001 diff.py:29(__call__)
#      6060    0.003    0.000    0.003    0.000 {built-in method math.floor}
#      8521    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
# 12180/12135    0.003    0.000    0.011    0.000 abc.py:121(__subclasscheck__)
#       242    0.003    0.000    0.409    0.002 z3base.py:260(generate_indexings)
#      1224    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     14424    0.003    0.000    0.004    0.000 library.py:242(xorder)
#         1    0.003    0.003    0.003    0.003 _parser.py:452(_parse_sub)
#        71    0.003    0.000    0.003    0.000 enum.py:1129(__new__)
#     35967    0.003    0.000    0.003    0.000 library.py:32(sub_exprs)
#      8520    0.003    0.000    0.003    0.000 {built-in method math.ceil}
#         1    0.003    0.003    0.043    0.043 __init__.py:169(fullmatch)
#         1    0.003    0.003    0.006    0.006 _parser.py:969(parse)
#      5608    0.003    0.000    0.023    0.000 z3.py:1571(sort)
#     23145    0.003    0.000    0.003    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
#   220/218    0.003    0.000    0.050    0.000 {built-in method builtins.next}
#      8184    0.003    0.000    0.047    0.000 z3.py:1201(_coerce_expr_merge)
#      4261    0.003    0.000    0.005    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#      9216    0.003    0.000    0.010    0.000 _polybase.py:838(mapparms)
#      6060    0.003    0.000    0.003    0.000 diff.py:255(get_h)
#     61588    0.003    0.000    0.003    0.000 z3types.py:48(from_param)
#      6060    0.002    0.000    0.002    0.000 coefs.py:286(_validate_acc)
#     21137    0.002    0.000    0.004    0.000 z3.py:1260(is_expr)
#      3312    0.002    0.000    0.038    0.000 z3.py:1535(cast)
#     35407    0.002    0.000    0.002    0.000 library.py:35(own_indices)
#      4928    0.002    0.000    0.025    0.000 process_library_terms.py:72(__neg__)
#      1920    0.002    0.000    0.007    0.000 diff.py:210(__mul__)
#     39234    0.002    0.000    0.002    0.000 z3.py:990(as_ast)
#       408    0.002    0.000    0.006    0.000 _polybase.py:512(__getstate__)
#         1    0.002    0.002    0.002    0.002 {method 'dot' of 'numpy.ndarray' objects}
#     18180    0.002    0.000    0.002    0.000 _linalg.py:314(_solve_dispatcher)
#     33799    0.002    0.000    0.002    0.000 library.py:287(sub_exprs)
#     33047    0.002    0.000    0.002    0.000 library.py:437(own_indices)
#     26931    0.002    0.000    0.002    0.000 library.py:538(sub_exprs)
#      1904    0.002    0.000    0.002    0.000 threading.py:1198(ident)
#      8560    0.002    0.000    0.003    0.000 library.py:36(<lambda>)
#      9221    0.002    0.000    0.002    0.000 {method 'rpartition' of 'str' objects}
#      6392    0.002    0.000    0.014    0.000 __init__.py:730(copy)
#        18    0.002    0.000    0.003    0.000 copyreg.py:107(_slotnames)
#     31816    0.002    0.000    0.007    0.000 z3.py:260(_get_ctx)
#      1676    0.002    0.000    0.005    0.000 library.py:324(__lt__)
#     26571    0.002    0.000    0.002    0.000 library.py:541(own_indices)
#      5376    0.002    0.000    0.045    0.000 library.py:580(<genexpr>)
#     27381    0.002    0.000    0.002    0.000 library.py:334(sub_exprs)
#   769/118    0.002    0.000    0.017    0.000 z3base.py:215(canonical_indexing_problem)
#      1744    0.002    0.000    0.019    0.000 z3.py:3234(IntVal)
#     18432    0.002    0.000    0.002    0.000 fromnumeric.py:2508(_all_dispatcher)
#         1    0.002    0.002  357.300  357.300 <string>:1(<module>)
#     14649    0.002    0.000    0.002    0.000 z3.py:451(is_ast)
#      1613    0.002    0.000    0.068    0.000 z3.py:1019(__eq__)
#         1    0.002    0.002    0.002    0.002 _compiler.py:37(_compile)
#      1744    0.001    0.000    0.003    0.000 z3core.py:2376(Z3_mk_numeral)
#        72    0.001    0.000    0.004    0.000 tasks.py:653(sleep)
#         1    0.001    0.001    0.001    0.001 {method 'fullmatch' of 're.Pattern' objects}
#         1    0.001    0.001    0.001    0.001 _compiler.py:511(_compile_info)
#         1    0.001    0.001    0.001    0.001 {method 'pop' of 'dict' objects}
#         1    0.001    0.001    0.001    0.001 _shape_base_impl.py:665(_dstack_dispatcher)
#         1    0.001    0.001    4.835    4.835 format.py:687(write_array)
#     16626    0.001    0.000    0.001    0.000 __init__.py:609(__missing__)
#     14641    0.001    0.000    0.001    0.000 fromnumeric.py:3063(_prod_dispatcher)
#     22477    0.001    0.000    0.001    0.000 z3.py:62(z3_debug)
#      2362    0.001    0.000    0.009    0.000 z3.py:3188(IntSort)
#      6272    0.001    0.000    0.003    0.000 {method 'index' of 'tuple' objects}
#       238    0.001    0.000    0.001    0.000 threading.py:1535(enumerate)
#     10320    0.001    0.000    0.001    0.000 multiarray.py:83(empty_like)
#      1138    0.001    0.000    0.001    0.000 z3.py:523(_to_ast_array)
#      1613    0.001    0.000    0.002    0.000 z3core.py:1896(Z3_mk_eq)
#        36    0.001    0.000    0.003    0.000 iostream.py:127(_event_pipe_gc)
#       445    0.001    0.000    0.038    0.000 z3.py:1889(And)
#         2    0.001    0.001    0.043    0.021 _methods.py:216(_std)
#     19246    0.001    0.000    0.001    0.000 z3.py:105(_z3_assert)
#      6960    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#       148    0.001    0.000    0.002    0.000 threading.py:1222(is_alive)
#   825/124    0.001    0.000    0.002    0.000 z3base.py:321(check_commutative_validity)
#         1    0.001    0.001    0.001    0.001 z3core.py:1612(Z3_mk_config)
#      2082    0.001    0.000    0.002    0.000 z3core.py:2870(Z3_get_sort_kind)
#      2362    0.001    0.000    0.002    0.000 z3core.py:88(_str_to_bytes)
#      6060    0.001    0.000    0.001    0.000 coefs.py:291(_validate_deriv)
#       366    0.001    0.000    0.020    0.000 z3.py:1922(Or)
#      1072    0.001    0.000    0.002    0.000 z3.py:497(_ctx_from_ast_arg_list)
#        36    0.001    0.000    0.008    0.000 iostream.py:118(_run_event_pipe_gc)
#       568    0.001    0.000    0.007    0.000 library.py:476(diff)
#      2362    0.001    0.000    0.002    0.000 z3core.py:1766(Z3_mk_int_sort)
#     83/81    0.001    0.000    0.012    0.000 {method 'run' of '_contextvars.Context' objects}
#      5824    0.001    0.000    0.001    0.000 {method 'copy' of 'list' objects}
#         1    0.001    0.001    4.836    4.836 _npyio_impl.py:503(save)
#      6392    0.001    0.000    0.001    0.000 {built-in method from_iterable}
#         1    0.001    0.001    4.882    4.882 utils.py:9(save)
#      6060    0.001    0.000    0.001    0.000 numeric.py:59(_zeros_like_dispatcher)
#       866    0.001    0.000    0.051    0.000 z3.py:1248(_coerce_expr_list)
#       618    0.001    0.000    0.008    0.000 z3.py:3294(Int)
#       245    0.001    0.000    0.036    0.000 z3.py:7062(assert_exprs)
#      5490    0.001    0.000    0.001    0.000 process_library_terms.py:104(<lambda>)
#         2    0.001    0.000    0.001    0.000 contextlib.py:299(helper)
#        38    0.001    0.000    0.002    0.000 {method 'set_result' of '_asyncio.Future' objects}
#      1294    0.001    0.000    0.001    0.000 z3core.py:3120(Z3_get_ast_kind)
#      6960    0.001    0.000    0.001    0.000 numeric.py:1433(_moveaxis_dispatcher)
#       866    0.001    0.000    0.022    0.000 z3.py:1241(_reduce)
#      2240    0.001    0.000    0.001    0.000 process_library_terms.py:85(__hash__)
#       206    0.001    0.000    0.020    0.000 z3.py:1399(If)
#        36    0.001    0.000    0.001    0.000 events.py:155(cancel)
#       204    0.001    0.000    0.018    0.000 library.py:508(symmetry)
#       356    0.001    0.000    0.001    0.000 {built-in method posix.getppid}
#      4260    0.001    0.000    0.001    0.000 numeric.py:212(_ones_like_dispatcher)
#      4261    0.001    0.000    0.001    0.000 multiarray.py:161(concatenate)
#      1744    0.001    0.000    0.001    0.000 z3.py:3222(_to_int_str)
#       618    0.001    0.000    0.001    0.000 z3core.py:1862(Z3_mk_const)
#       245    0.001    0.000    0.116    0.000 z3.py:7148(check)
#         1    0.000    0.000    0.001    0.001 process_library_terms.py:57(make_domains)
#       118    0.000    0.000    0.001    0.000 z3core.py:4085(Z3_mk_solver)
#         2    0.000    0.000    0.004    0.002 _methods.py:110(_mean)
#       478    0.000    0.000    0.002    0.000 z3.py:1151(_to_expr_ref)
#       618    0.000    0.000    0.001    0.000 z3core.py:1746(Z3_mk_string_symbol)
#      1784    0.000    0.000    0.001    0.000 z3base.py:116(__lt__)
#       460    0.000    0.000    0.001    0.000 library.py:509(transpose)
#       696    0.000    0.000    0.001    0.000 z3core.py:1761(Z3_mk_bool_sort)
#        39    0.000    0.000    0.001    0.000 base_events.py:814(_call_soon)
#       164    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.295    0.295 library.py:50(generate_terms_to)
#      2160    0.000    0.000    0.000    0.000 diff.py:22(__init__)
#        36    0.000    0.000    0.000    0.000 base_events.py:447(create_future)
#       696    0.000    0.000    0.003    0.000 z3.py:1731(BoolSort)
#       445    0.000    0.000    0.001    0.000 z3core.py:1931(Z3_mk_and)
#       272    0.000    0.000    0.003    0.000 z3.py:6507(get_interp)
#      1604    0.000    0.000    0.002    0.000 z3.py:555(_sort_kind)
#         2    0.000    0.000    0.005    0.002 fromnumeric.py:3476(mean)
#       127    0.000    0.000    0.009    0.000 z3base.py:340(check_subexpr_cv)
#      4260    0.000    0.000    0.000    0.000 multiarray.py:678(result_type)
#    279/79    0.000    0.000    0.001    0.000 library.py:99(valid_prime_lists)
#       816    0.000    0.000    0.001    0.000 z3.py:491(_ast_kind)
#      1356    0.000    0.000    0.001    0.000 z3.py:144(_get_args)
#       316    0.000    0.000    0.001    0.000 z3.py:1446(_mk_bin)
#      4260    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#       811    0.000    0.000    0.001    0.000 z3.py:1881(_has_probe)
#      2758    0.000    0.000    0.000    0.000 z3.py:8770(is_probe)
#       366    0.000    0.000    0.000    0.000 z3core.py:1936(Z3_mk_or)
#       618    0.000    0.000    0.002    0.000 z3.py:124(to_symbol)
#     151/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#       272    0.000    0.000    0.000    0.000 z3core.py:1901(Z3_mk_distinct)
#         2    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.428    0.428 process_library_terms.py:38(make_libraries)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#      1604    0.000    0.000    0.002    0.000 z3.py:568(kind)
#       272    0.000    0.000    0.008    0.000 z3.py:6634(__getitem__)
#        90    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#   651/184    0.000    0.000    0.014    0.000 z3base.py:223(emap)
#         2    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#       272    0.000    0.000    0.001    0.000 z3core.py:3150(Z3_get_numeral_string)
#        13    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#       272    0.000    0.000    0.014    0.000 z3.py:1040(__ne__)
#      1088    0.000    0.000    0.002    0.000 z3.py:1283(is_app)
#       576    0.000    0.000    0.003    0.000 process_library_terms.py:76(__mul__)
#      1604    0.000    0.000    0.002    0.000 z3.py:2355(is_int)
#         2    0.000    0.000    0.043    0.022 fromnumeric.py:3605(std)
#         1    0.000    0.000    0.003    0.003 _linalg.py:2566(norm)
#       544    0.000    0.000    0.000    0.000 z3core.py:3100(Z3_get_ast_hash)
#       544    0.000    0.000    0.000    0.000 z3core.py:2975(Z3_func_decl_to_ast)
#       272    0.000    0.000    0.002    0.000 z3.py:1061(decl)
#        77    0.000    0.000    0.000    0.000 events.py:36(__init__)
#       316    0.000    0.000    0.000    0.000 z3core.py:1941(Z3_mk_add)
#      2373    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       272    0.000    0.000    0.001    0.000 z3.py:1076(num_args)
#         1    0.000    0.000    0.000    0.000 format.py:358(header_data_from_array_1_0)
#       164    0.000    0.000    0.001    0.000 base_events.py:734(time)
#       241    0.000    0.000    0.010    0.000 z3.py:2662(__le__)
#        32    0.000    0.000    0.000    0.000 socket.py:621(send)
#        38    0.000    0.000    0.001    0.000 base_events.py:785(call_soon)
#       148    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 format.py:386(_wrap_header)
#       206    0.000    0.000    0.000    0.000 z3core.py:1911(Z3_mk_ite)
#       148    0.000    0.000    0.001    0.000 threading.py:1155(_wait_for_tstate_lock)
#       206    0.000    0.000    0.008    0.000 z3.py:2701(__ge__)
#        36    0.000    0.000    0.002    0.000 futures.py:315(_set_result_unless_cancelled)
#       296    0.000    0.000    0.000    0.000 z3base.py:346(<lambda>)
#       272    0.000    0.000    0.004    0.000 z3base.py:297(<lambda>)
#       544    0.000    0.000    0.001    0.000 z3.py:440(hash)
#       840    0.000    0.000    0.000    0.000 z3base.py:98(__eq__)
#       241    0.000    0.000    0.000    0.000 z3core.py:1991(Z3_mk_le)
#       272    0.000    0.000    0.000    0.000 z3core.py:3392(Z3_model_get_const_interp)
#       272    0.000    0.000    0.003    0.000 z3.py:3012(as_long)
#        38    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#      1302    0.000    0.000    0.000    0.000 z3.py:71(_is_int)
#      2634    0.000    0.000    0.000    0.000 {built-in method sys.getdefaultencoding}
#       412    0.000    0.000    0.005    0.000 z3.py:3173(_py2expr)
#        38    0.000    0.000    0.000    0.000 events.py:111(__init__)
#       206    0.000    0.000    0.000    0.000 z3core.py:2001(Z3_mk_ge)
#         2    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#       220    0.000    0.000    0.009    0.000 z3.py:2468(__add__)
#        38    0.000    0.000    0.001    0.000 base_events.py:767(call_at)
#         1    0.000    0.000    0.000    0.000 format.py:244(dtype_to_descr)
#       544    0.000    0.000    0.002    0.000 z3.py:1309(is_const)
#       544    0.000    0.000    0.001    0.000 z3.py:748(as_ast)
#       245    0.000    0.000    0.036    0.000 z3.py:7081(add)
#       240    0.000    0.000    0.000    0.000 diff.py:149(__mul__)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.calcsize}
#        55    0.000    0.000    0.004    0.000 z3.py:9070(AtMost)
#       272    0.000    0.000    0.000    0.000 z3core.py:3447(Z3_is_as_array)
#         1    0.000    0.000    0.001    0.001 {method 'mean' of 'numpy.generic' objects}
#       272    0.000    0.000    0.000    0.000 z3core.py:3005(Z3_get_arity)
#       272    0.000    0.000    0.000    0.000 z3core.py:3075(Z3_get_app_decl)
#       272    0.000    0.000    0.000    0.000 z3.py:6740(is_as_array)
#       272    0.000    0.000    0.000    0.000 z3core.py:3080(Z3_get_app_num_args)
#       206    0.000    0.000    0.003    0.000 z3base.py:229(imap)
#       272    0.000    0.000    0.000    0.000 z3core.py:95(_to_pystr)
#       272    0.000    0.000    0.002    0.000 z3.py:2443(is_int)
#       118    0.000    0.000    0.006    0.000 z3.py:6949(__init__)
#       544    0.000    0.000    0.001    0.000 z3.py:1036(__hash__)
#        36    0.000    0.000    0.000    0.000 events.py:72(cancel)
#        38    0.000    0.000    0.001    0.000 base_events.py:743(call_later)
#       272    0.000    0.000    0.001    0.000 z3.py:3025(as_string)
#        40    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        55    0.000    0.000    0.000    0.000 z3core.py:2950(Z3_mk_atmost)
#        39    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#       544    0.000    0.000    0.001    0.000 z3.py:367(__hash__)
#       206    0.000    0.000    0.003    0.000 z3base.py:370(free_z3_var)
#       272    0.000    0.000    0.000    0.000 z3.py:768(arity)
#        91    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       544    0.000    0.000    0.001    0.000 z3base.py:82(__hash__)
#       127    0.000    0.000    0.004    0.000 z3.py:7177(model)
#        40    0.000    0.000    0.001    0.000 process_library_terms.py:160(constant_tw)
#       127    0.000    0.000    0.000    0.000 z3core.py:3384(Z3_model_dec_ref)
#        37    0.000    0.000    0.006    0.000 z3base.py:314(lexico_le)
#       336    0.000    0.000    0.000    0.000 z3base.py:90(__lt__)
#       127    0.000    0.000    0.000    0.000 z3core.py:3380(Z3_model_inc_ref)
#       118    0.000    0.000    0.000    0.000 z3core.py:4133(Z3_solver_inc_ref)
#       170    0.000    0.000    0.000    0.000 typing.py:392(inner)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#        82    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#        96    0.000    0.000    0.004    0.000 z3.py:2481(__radd__)
#        77    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
#        38    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#        26    0.000    0.000    0.000    0.000 iostream.py:655(write)
#      1304    0.000    0.000    0.000    0.000 z3types.py:158(from_param)
#        64    0.000    0.000    0.000    0.000 process_library_terms.py:113(multi_index_iterator)
#       363    0.000    0.000    0.000    0.000 z3.py:6908(__eq__)
#       747    0.000    0.000    0.005    0.000 z3.py:239(main_ctx)
#        81    0.000    0.000    0.000    0.000 z3.py:1749(BoolVal)
#        71    0.000    0.000    0.003    0.000 enum.py:726(__call__)
#      1088    0.000    0.000    0.000    0.000 z3types.py:56(from_param)
#       156    0.000    0.000    0.000    0.000 enum.py:1544(_get_value)
#       127    0.000    0.000    0.000    0.000 z3.py:6422(__del__)
#       127    0.000    0.000    0.000    0.000 z3.py:6416(__init__)
#       200    0.000    0.000    0.000    0.000 library.py:91(<genexpr>)
#       268    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#       118    0.000    0.000    0.009    0.000 z3.py:6962(__del__)
#        32    0.000    0.000    0.001    0.000 process_library_terms.py:247(make_basis)
#       206    0.000    0.000    0.003    0.000 z3base.py:217(next_z3_var)
#        34    0.000    0.000    0.000    0.000 library.py:246(blank_derivative)
#         1    0.000    0.000    0.001    0.001 process_library_terms.py:352(make_weights)
#       272    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        13    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#        34    0.000    0.000    0.000    0.000 library.py:75(partition_to_prime)
#       255    0.000    0.000    0.000    0.000 z3base.py:324(<lambda>)
#         6    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#        33    0.000    0.000    0.002    0.000 z3.py:2675(__lt__)
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        30    0.000    0.000    0.000    0.000 process_library_terms.py:15(__init__)
#        33    0.000    0.000    0.000    0.000 z3core.py:1986(Z3_mk_lt)
#        31    0.000    0.000    0.000    0.000 enum.py:1551(__or__)
#       526    0.000    0.000    0.000    0.000 z3types.py:190(from_param)
#         8    0.000    0.000    0.000    0.000 process_library_terms.py:198(stf_rank2_basis)
#         4    0.000    0.000    0.000    0.000 _methods.py:76(_count_reduce_items)
#         1    0.000    0.000    0.000    0.000 _parser.py:512(_parse)
#         4    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#       618    0.000    0.000    0.000    0.000 z3types.py:40(from_param)
#         1    0.000    0.000    0.000    0.000 format.py:434(_write_array_header)
#        59    0.000    0.000    0.000    0.000 z3core.py:1886(Z3_mk_true)
#         1    0.000    0.000    0.009    0.009 _compiler.py:740(compile)
#         6    0.000    0.000    0.001    0.000 zmqstream.py:607(_handle_events)
#         8    0.000    0.000    0.000    0.000 process_library_terms.py:235(full_basis)
#         8    0.000    0.000    0.000    0.000 process_library_terms.py:220(anti_rank2_basis)
#         8    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#        34    0.000    0.000    0.000    0.000 typing.py:1180(__call__)
#    126/36    0.000    0.000    0.000    0.000 library.py:730(partition)
#         7    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#         6    0.000    0.000    0.001    0.000 zmqstream.py:580(_run_callback)
#        37    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#       245    0.000    0.000    0.000    0.000 z3.py:6902(__init__)
#         6    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#         4    0.000    0.000    0.000    0.000 socket.py:698(send_multipart)
#        36    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 _compiler.py:570(isstring)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         3    0.000    0.000    0.000    0.000 iostream.py:616(_flush)
#        18    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       195    0.000    0.000    0.000    0.000 z3base.py:331(<genexpr>)
#         1    0.000    0.000    0.001    0.001 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.005    0.005 z3.py:192(__init__)
#         7    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#       151    0.000    0.000    0.000    0.000 base_events.py:2004(get_debug)
#         2    0.000    0.000    0.000    0.000 session.py:754(send)
#         1    0.000    0.000    0.000    0.000 format.py:202(magic)
#         1    0.000    0.000    0.003    0.003 _compiler.py:573(_code)
#         4    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         5    0.000    0.000    0.000    0.000 typeof.py:240(_typeof_ndarray)
#         1    0.000    0.000    0.000    0.000 z3core.py:1568(Z3_set_error_handler)
#         5    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#        36    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 typing.py:1074(_generic_class_getitem)
#         4    0.000    0.000    0.001    0.000 ioloop.py:742(_run_callback)
#         8    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#        34    0.000    0.000    0.000    0.000 <string>:2(__setattr__)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#        13    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         5    0.000    0.000    0.000    0.000 common.py:49(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _pickle.loads}
#        47    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         7    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 shape_base.py:139(atleast_3d)
#         1    0.000    0.000    0.000    0.000 _parser.py:178(getwidth)
#        22    0.000    0.000    0.000    0.000 z3core.py:1891(Z3_mk_false)
#         6    0.000    0.000    0.001    0.000 zmqstream.py:648(_handle_recv)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.001    0.001 library.py:429(__repr__)
#         8    0.000    0.000    0.000    0.000 process_library_terms.py:181(scalar_basis)
#        34    0.000    0.000    0.000    0.000 library.py:398(complexity)
#         4    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         2    0.000    0.000    0.050    0.025 utils.py:6(regex_find)
#        12    0.000    0.000    0.000    0.000 typing.py:1285(__hash__)
#       118    0.000    0.000    0.000    0.000 typing.py:2193(assert_type)
#         8    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#     30/17    0.000    0.000    0.000    0.000 abstract.py:121(__hash__)
#         5    0.000    0.000    0.000    0.000 npytypes.py:444(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3129(_bind)
#        34    0.000    0.000    0.000    0.000 library.py:19(complexity)
#         2    0.000    0.000    0.000    0.000 {built-in method now}
#         1    0.000    0.000    0.000    0.000 history.py:845(writeout_cache)
#         1    0.000    0.000    0.000    0.000 _parser.py:231(__init__)
#        14    0.000    0.000    0.000    0.000 typing.py:1215(__setattr__)
#        26    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
# ...
#        34    0.000    0.000    0.000    0.000 library.py:238(complexity)
#         3    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        26    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 session.py:649(msg)
#         8    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#         7    0.000    0.000    0.000    0.000 functools.py:902(wrapper)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         7    0.000    0.000    0.000    0.000 functools.py:816(dispatch)
#         2    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        94    0.000    0.000    0.000    0.000 typing.py:2182(cast)
#        36    0.000    0.000    0.000    0.000 base_events.py:1904(_timer_handle_cancelled)
#         2    0.000    0.000    0.000    0.000 _parser.py:240(__next)
#         1    0.000    0.000    0.000    0.000 context.py:617(install_possible_conversions)
#         1    0.000    0.000    0.000    0.000 _utils_impl.py:711(drop_metadata)
#         4    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:660(_search_new_conversions)
#         7    0.000    0.000    0.000    0.000 dispatcher.py:679(typeof_pyval)
#        14    0.000    0.000    0.000    0.000 typing.py:1161(_is_dunder)
#         6    0.000    0.000    0.000    0.000 typing.py:1492(__subclasscheck__)
#         7    0.000    0.000    0.000    0.000 typeof.py:27(typeof)
#         6    0.000    0.000    0.000    0.000 typing.py:1221(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 session.py:675(sign)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         2    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         2    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#         2    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#        36    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#        65    0.000    0.000    0.000    0.000 library.py:21(<genexpr>)
#         6    0.000    0.000    0.000    0.000 typeconv.py:40(check_compatible)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#        26    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:282(nopython_signatures)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.007    0.007 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3268(bind)
#         2    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         7    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         8    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         1    0.000    0.000    0.000    0.000 history.py:833(_writeout_input_cache)
#         4    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 contextlib.py:772(__init__)
#        40    0.000    0.000    0.000    0.000 _collections_abc.py:435(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         6    0.000    0.000    0.000    0.000 abstract.py:124(__eq__)
#        26    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 process_library_terms.py:338(all_rank2_irreps)
#         2    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         4    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 format.py:410(_wrap_header_guess_version)
#         1    0.000    0.000    0.000    0.000 z3core.py:3536(Z3_set_ast_print_mode)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         5    0.000    0.000    0.000    0.000 abstract.py:49(_intern)
#         4    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         2    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         7    0.000    0.000    0.000    0.000 weakref.py:414(__getitem__)
#        23    0.000    0.000    0.000    0.000 npytypes.py:482(key)
#         2    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         5    0.000    0.000    0.000    0.000 numpy_support.py:222(map_layout)
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 typing.py:1174(__init__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#        14    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 process_library_terms.py:321(__post_init__)
#         7    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         9    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#         1    0.000    0.000    0.000    0.000 library.py:257(__repr__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2945(apply_defaults)
#         6    0.000    0.000    0.000    0.000 numpy_support.py:86(from_dtype)
#         4    0.000    0.000    0.000    0.000 _ufunc_config.py:458(_no_nep50_warning)
#         2    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#         5    0.000    0.000    0.000    0.000 base_events.py:1894(_add_callback)
#         8    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         5    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         4    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         8    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         4    0.000    0.000    0.000    0.000 typing.py:1088(<genexpr>)
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2892(args)
#         9    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x104657320}
#         6    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#         1    0.000    0.000    0.000    0.000 context.py:561(can_convert)
#         1    0.000    0.000    0.000    0.000 typeconv.py:49(set_compatible)
#         1    0.000    0.000    0.000    0.000 futures.py:398(_call_set_state)
#         1    0.000    0.000    0.000    0.000 _compiler.py:436(_get_literal_prefix)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         7    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.000    0.000 library.py:28(__repr__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#        13    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         5    0.000    0.000    0.000    0.000 misc.py:63(unliteral)
#        10    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 _compiler.py:407(_generate_overlap_table)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         3    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#         2    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         2    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 typeof.py:130(_typeof_int)
#         2    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 npytypes.py:503(can_convert_to)
#         1    0.000    0.000    0.000    0.000 base_events.py:838(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 __init__.py:146(_DType_reduce)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#        19    0.000    0.000    0.000    0.000 abstract.py:96(key)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.001    0.001 decorator.py:229(fun)
#         1    0.000    0.000    0.000    0.000 utils.py:504(bit_length)
#         1    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         1    0.000    0.000    0.000    0.000 format.py:197(_check_version)
#         1    0.000    0.000    0.000    0.000 numpy_support.py:204(map_arrayscalar_type)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         2    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         1    0.000    0.000    0.000    0.000 _parser.py:176(append)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         4    0.000    0.000    0.000    0.000 enum.py:810(__getitem__)
#         3    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         2    0.000    0.000    0.000    0.000 typing.py:262(_collect_parameters)
#         4    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 _parser.py:953(fix_flags)
#         1    0.000    0.000    0.000    0.000 inspect.py:2915(kwargs)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:718(<lambda>)
#         1    0.000    0.000    0.000    0.000 _parser.py:77(__init__)
#         1    0.000    0.000    0.000    0.000 typeof.py:145(_typeof_numpy_scalar)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#        10    0.000    0.000    0.000    0.000 inspect.py:2804(kind)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 _parser.py:293(tell)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3471(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 library.py:318(complexity)
#         2    0.000    0.000    0.000    0.000 typing.py:295(_check_generic)
#         1    0.000    0.000    0.000    0.000 z3core.py:1616(Z3_del_config)
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.BufferedWriter' objects}
#         1    0.000    0.000    0.000    0.000 weakref.py:427(__setitem__)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 _parser.py:256(match)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 inspect.py:2792(name)
#         2    0.000    0.000    0.000    0.000 z3base.py:35(__repr__)
#         7    0.000    0.000    0.000    0.000 {built-in method _abc.get_cache_token}
#         1    0.000    0.000    0.000    0.000 _parser.py:261(get)
#         2    0.000    0.000    0.000    0.000 typing.py:166(_type_convert)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.bin}
#         1    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.set_compatible}
#         5    0.000    0.000    0.000    0.000 abstract.py:118(__str__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         4    0.000    0.000    0.000    0.000 typing.py:1273(<genexpr>)
#         5    0.000    0.000    0.000    0.000 abstract.py:93(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 abstract.py:20(_autoincr)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 process_library_terms.py:236(set_LT_scale)
#         2    0.000    0.000    0.000    0.000 _parser.py:83(groups)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _parser.py:168(__getitem__)
#         1    0.000    0.000    0.000    0.000 _parser.py:164(__len__)
#         4    0.000    0.000    0.000    0.000 inspect.py:3085(parameters)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 _parser.py:113(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 inspect.py:2884(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 z3base.py:25(__repr__)
#         2    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:3600(_std_dispatcher)
#         2    0.000    0.000    0.000    0.000 z3types.py:32(from_param)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 contextlib.py:775(__enter__)
#         1    0.000    0.000    0.000    0.000 contextlib.py:778(__exit__)
#         1    0.000    0.000    0.000    0.000 z3base.py:30(__repr__)
#         1    0.000    0.000    0.000    0.000 shape_base.py:135(_atleast_3d_dispatcher)
#         1    0.000    0.000    0.000    0.000 templates.py:49(args)
#         1    0.000    0.000    0.000    0.000 _compiler.py:428(_get_iscased)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 _npyio_impl.py:499(_save_dispatcher)
#         1    0.000    0.000    0.000    0.000 _linalg.py:2562(_norm_dispatcher)
#         1    0.000    0.000    0.000    0.000 base_events.py:720(is_closed)
#         1    0.000    0.000    0.000    0.000 abstract.py:151(can_convert_from)

# %%
from scipy.stats._stats import gaussian_kernel_estimate
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from IPython.display import HTML

def coarse_grain_slice(t, sigma, field='rho', component=None):
    pt_pos = positions[:, :, t]
    weights = np.ones(pt_pos.shape[0], dtype=np.float64)
    if field == 'v':
        weights *= vs[:, component, t]
    xx, yy = np.meshgrid(np.linspace(0, 1, cg_res), np.linspace(0, 1, cg_res))
    xi = np.vstack([xx.ravel(), yy.ravel()]).T

    sigma_sq = sigma ** 2
    # Check scipy version. If it's lower than 1.10, use inverse_covariance, otherwise use Cholesky
    if int(scipy.__version__.split(".")[0]) <= 1 and int(scipy.__version__.split(".")[1]) < 10:
        inv_cov = np.eye(2) / sigma_sq
    else:
        inv_cov = np.eye(2) * sigma_sq
        inv_cov = np.linalg.cholesky(inv_cov[::-1, ::-1]).T[::-1, ::-1]
    density = gaussian_kernel_estimate['double'](pt_pos, weights[:, None], xi, inv_cov,
                                                 np.float64)
    output = np.reshape(density[:, 0], xx.shape) / 1e4
    return output

t = 100
sigma = kernel_sigma
rho_cg = coarse_grain_slice(t, sigma, field='rho')
vx_cg = coarse_grain_slice(t, sigma, field='v', component=0)
vy_cg = coarse_grain_slice(t, sigma, field='v', component=1)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10))
im1 = ax1.imshow(rho_cg)
#colorbar
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes("right", size="5%", pad=0.05)
cb1 = plt.colorbar(im1, cax=cax1)

im2 = ax2.imshow(vx_cg)
#colorbar
divider2 = make_axes_locatable(ax2)
cax2 = divider2.append_axes("right", size="5%", pad=0.05)
cb2 = plt.colorbar(im2, cax=cax2)

ax1.set_ylabel('rho')
ax2.set_ylabel('rho[v_x]')
# Out:
# Text(0, 0.5, 'rho[v_x]')

# %%
from commons.identify_models import *
import copy

#srd = load('Q_gauss1024.npy', 1)
libs = srd.libs

reg_opts_list = []
for irrep in srd.irreps:
    #print(np.linalg.norm(libs[irrep].Q, axis=0))
    # for regression we now need to construct a Scaler, Initializer, ModelIterator, and Threshold
    scaler = Scaler(sub_inds=None, char_sizes=libs[irrep].col_weights, row_norms=None, unit_rows=True, train_fraction=1)
    #init = Initializer(method='combinatorial', start_k=3)
    #init = Initializer(method='combinatorial', start_k=9999)
    init = Initializer(method='power', start_k=10)
    #res = Residual(residual_type='fixed_column', anchor_col=0)
    #res = Residual(residual_type='dominant_balance')
    res = Residual(residual_type='matrix_relative')
    
    iterator = ModelIterator(max_k=10, backward_forward=True, max_passes=3)
    #iterator = ModelIterator(max_k=len(libs[irrep].terms), backward_forward=False, max_passes=1)
    thres = Threshold(threshold_type='jump', gamma=1.3, delta=1e-8, n_terms=None)
    #thres = Threshold(threshold_type='information', ic=AIC)
    
    opts = {'scaler': scaler, 'initializer': init, 'residual': res,
            'model_iterator': iterator, 'threshold': thres}
    opts['verbose'] = False
    opts['inhomog'] = False
    opts['inhomog_col'] = None
    reg_opts_list.append(opts)

eqs, lambdas, reg_results, derived_eqs, excluded_terms = interleave_identify([libs[i] for i in srd.irreps], 
reg_opts_list, threshold=2e-2, experimental=True, report_accuracy=True)
#reg_opts_list, threshold=5e-2, experimental=True)
# Out:
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 3 ---
# [0.01 s]
# Identified model: 1 · ∂t ρ + ∂α ρ[v_α] = 0 (order 3, residual 1.81e-06)
# (Accuracy = 1.41e-06)
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 3 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 3 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 3 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 4 ---
# [0.01 s]
# Identified model: -0.996 · ρ · ∂α² ρ + 0.268 · ρ · ∂t² ρ + ∂α² ρ + -0.27 · ∂t² ρ = 0 (order 4, residual 6.61e-03)
# (Accuracy = 5.94e-03)
# [0.08 s]
# Identified model: 0.714 · ρ + -0.709 · ρ · ρ + ρ · ρ[v_α · v_α] + -0.992 · ρ[v_α · v_α] = 0 (order 4, residual 1.48e-02)
# (Accuracy = 1.52e-02)
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 4 ---
# [0.01 s]
# Identified model: -0.997 · ρ · ∂α ρ + -0.191 · ρ · ∂t ρ[v_α] + ∂α ρ + 0.192 · ∂t ρ[v_α] = 0 (order 4, residual 7.74e-03)
# (Accuracy = 5.49e-03)
# [0.09 s]
# Identified model: -1 · ρ · ∂α ρ + ∂α ρ = 0 (order 4, residual 1.21e-02)
# (Accuracy = 6.20e-02)
# [0.39 s]
# Identified model: ∂α ρ + 4.33e-05 · ∂α ∂β² ρ + 0.158 · ∂t ρ[v_α] + 0.16 · ∂β ρ[v_α · v_β] = 0 (order 4, residual 1.59e-02)
# (Accuracy = 1.05e-02)
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 4 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 4 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 5 ---
# [0.01 s]
# Identified model: -0.988 · ρ · ∂t ρ + ∂t ρ = 0 (order 5, residual 1.15e-02)
# (Accuracy = 4.91e-02)
# [0.11 s]
# Identified model: ρ + -0.977 · ρ · ρ = 0 (order 5, residual 1.35e-02)
# (Accuracy = 6.37e-02)
# [0.78 s]
# Identified model: ∂α² ρ + -0.148 · ∂t² ρ + 1.57e-05 · ∂t² ∂α² ρ + 0.191 · ∂α ∂β ρ[v_α · v_β] = 0 (order 5, residual 1.28e-02)
# (Accuracy = 1.60e-02)
# [0.80 s]
# Identified model: ∂α² ρ + -0.192 · ∂t² ρ + 0.202 · ∂α ∂β ρ[v_α · v_β] = 0 (order 5, residual 1.66e-02)
# (Accuracy = 2.87e-02)
# [0.83 s]
# Identified model: ∂α ρ · ρ[v_α] + 0.163 · ρ[v_α] · ∂t ρ[v_α] + 0.0936 · ∂α ρ[v_α · v_β · v_β] = 0 (order 5, residual 1.64e-02)
# (Accuracy = 1.21e-02)
# [0.85 s]
# Identified model: ∂α ρ · ρ[v_α] + 0.0853 · ∂t ρ[v_α · v_α] + 0.0804 · ∂α ρ[v_α · v_β · v_β] = 0 (order 5, residual 1.71e-02)
# (Accuracy = 1.12e-02)
# [0.87 s]
# Identified model: 0.149 · ρ + ρ[v_α] · ρ[v_α] + -0.978 · ρ[v_α · v_α] = 0 (order 5, residual 1.74e-02)
# (Accuracy = 4.91e-02)
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 5 ---
# [0.02 s]
# Identified model: ρ · ρ[v_α] + -0.727 · ρ · ρ[v_α · v_β · v_β] + -0.997 · ρ[v_α] + 0.718 · ρ[v_α · v_β · v_β] = 0 (order 5, residual 5.61e-03)
# (Accuracy = 7.83e-03)
# [0.04 s]
# Identified model: ρ · ρ[v_α] + -0.992 · ρ[v_α] = 0 (order 5, residual 1.18e-02)
# (Accuracy = 5.39e-02)
# [0.37 s]
# Identified model: ∂α ρ + 0.171 · ∂t ρ[v_α] + 0.173 · ∂β ρ[v_α · v_β] = 0 (order 5, residual 1.38e-02)
# (Accuracy = 1.80e-02)
# [0.45 s]
# Identified model: -0.642 · ∂α ρ · ∂β² ρ + ∂β ρ · ∂α ∂β ρ = 0 (order 5, residual 1.78e-02)
# (Accuracy = 3.35e-01)
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 5 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 5 ---
# [0.01 s]
# Identified model: ρ · ρ[v_α · v_β] + -0.976 · ρ[v_α · v_β] = 0 (order 5, residual 1.38e-02)
# (Accuracy = 5.01e-02)

# %%
import numpy as np
import matplotlib.pyplot as plt
for i, res in enumerate(reg_results):
    all_lambdas = res.all_lambdas
    print(all_lambdas)
    all_xis = res.all_xis
    xi_values = res.xi
    sublibrary_terms = res.sublibrary
    equations = []
    #equation_terms = [f"{xi:.1e} {term}" for xi, term in zip(xi_values, sublibrary_terms) if abs(xi) > 1e-15]
    #equation_string = " + ".join(equation_terms)
    equation_string = str(eqs[i].pstr(**{'num_format': '{0:.3g}', 'latex_output': False}))

    
    plt.figure(figsize=(8, 5))
    plt.scatter(range(1, len(all_lambdas) + 1), all_lambdas, color='b', label="Lambda values")
    
    # Set log scale for y-axis
    plt.yscale("log")
    
    plt.xlabel("Equation Index")
    plt.ylabel("Lambda Values (log scale)")
    plt.title(f"Equation: {equation_string}")  # Use the computed equation as the title
    plt.xticks(range(1, len(all_lambdas) + 1))  # Ensure x-axis ticks match the number of equations
    plt.legend()
    plt.grid(True, which="both", linestyle="--", linewidth=0.5)
    
    plt.show()
# Out:
# [8.119e-01 1.812e-06 1.803e-06 1.792e-06 1.783e-06 1.777e-06 1.769e-06
#  1.769e-06]
# [0.177 0.013 0.011 0.007 0.006 0.006 0.006 0.006 0.006 0.006]
# [0.338 0.031 0.026 0.015 0.015 0.014 0.014 0.014 0.014 0.014]
# [0.139 0.012 0.012 0.008 0.008 0.007 0.007 0.007 0.007 0.007]
# [0.139 0.012 0.012 0.012 0.011 0.011 0.01  0.01  0.01  0.01 ]
# [0.13  0.096 0.027 0.016 0.016 0.016 0.015 0.015 0.015 0.015]
# [0.165 0.012 0.009 0.009 0.009 0.008 0.008 0.008 0.008 0.008]
# [0.148 0.013 0.011 0.01  0.009 0.009 0.007 0.007 0.007 0.007]
# [0.074 0.045 0.017 0.013 0.011 0.011 0.011 0.01  0.01  0.01 ]
# [0.073 0.045 0.017 0.016 0.015 0.015 0.014 0.014 0.014 0.014]
# [0.046 0.023 0.016 0.016 0.015 0.015 0.015 0.015 0.015 0.015]
# [0.045 0.023 0.017 0.016 0.015 0.015 0.015 0.015 0.015 0.015]
# [0.209 0.026 0.017 0.017 0.017 0.016 0.016 0.016 0.016 0.016]
# [0.156 0.012 0.01  0.006 0.006 0.005 0.005 0.005 0.005 0.005]
# [0.154 0.012 0.01  0.009 0.008 0.008 0.008 0.008 0.008 0.008]
# [0.032 0.018 0.014 0.011 0.01  0.009 0.009 0.009 0.009 0.009]
# [0.031 0.018 0.017 0.017 0.016 0.016 0.016 0.016 0.016 0.016]
# [0.192 0.014 0.012 0.011 0.011 0.01  0.01  0.009 0.009 0.009]

# %%
from commons.identify_models import *
import copy

#srd = load('Q_gauss1024.npy', 1)
libs = srd.libs

reg_opts_list = []
for irrep in srd.irreps:
    #print(np.linalg.norm(libs[irrep].Q, axis=0))
    # for regression we now need to construct a Scaler, Initializer, ModelIterator, and Threshold
    scaler = Scaler(sub_inds=None, char_sizes=libs[irrep].col_weights, row_norms=None, unit_rows=True, train_fraction=0.8)
    init = Initializer(method='combinatorial', start_k=3)
    #init = Initializer(method='combinatorial', start_k=9999)
    #init = Initializer(method='power', start_k=15)
    #res = Residual(residual_type='fixed_column', anchor_col=0)
    #res = Residual(residual_type='dominant_balance')
    res = Residual(residual_type='accuracy')
    
    iterator = ModelIterator(max_k=15, backward_forward=True, max_passes=3)
    #iterator = ModelIterator(max_k=len(libs[irrep].terms), backward_forward=False, max_passes=1)
    thres = Threshold(threshold_type='jump', gamma=1.5, delta=1e-8, n_terms=None)
    #thres = Threshold(threshold_type='information', ic=AIC)
    
    opts = {'scaler': scaler, 'initializer': init, 'residual': res,
            'model_iterator': iterator, 'threshold': thres}
    opts['verbose'] = False
    opts['inhomog'] = False
    opts['inhomog_col'] = None
    reg_opts_list.append(opts)

eqs, lambdas, reg_results, derived_eqs, excluded_terms = interleave_identify([libs[i] for i in srd.irreps], 
#reg_opts_list, threshold=2e-2, experimental=True)
reg_opts_list, threshold=3e-2, experimental=True)
# Out:
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 1 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 2 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 3 ---
# [0.01 s]
# Identified model: ∂t ρ + 1 · ∂α ρ[v_α] = 0 (order 3, train res 1.46e-06, test res 1.20e-06)
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 3 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 3 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 3 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 4 ---
# [0.02 s]
# Identified model: -0.986 · ρ · ∂α² ρ + 0.278 · ρ · ∂t² ρ + ∂α² ρ + -0.282 · ∂t² ρ = 0 (order 4, train res 5.85e-03, test res 7.16e-03)
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 4 ---
# [0.02 s]
# Identified model: ρ · ∂α ρ + 0.198 · ρ · ∂t ρ[v_α] + -0.998 · ∂α ρ + -0.197 · ∂t ρ[v_α] = 0 (order 4, train res 5.47e-03, test res 5.44e-03)
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 4 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 4 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 0 AT COMPLEXITY 5 ---
# --- WORKING ON LIBRARY WITH IRREP Rank 1 AT COMPLEXITY 5 ---
# --- WORKING ON LIBRARY WITH IRREP Antisymmetric rank 2 AT COMPLEXITY 5 ---
# --- WORKING ON LIBRARY WITH IRREP Symmetric trace-free rank 2 AT COMPLEXITY 5 ---
# [0.08 s]
# Identified model: -0.5 · ∂γ² ρ[v_α · v_β] + ∂α ∂γ ρ[v_β · v_γ] + -0.5 · ∂α ∂β ρ[v_γ · v_γ] = 0 (order 5, train res 2.38e-16, test res 2.68e-16)

# %%
print(srd.scale_dict)
for irrep in srd.irreps:
    # don't forget preprocessing
    Q = srd.libs[irrep].Q/srd.libs[irrep].col_weights # reweight columns
    for i in range(Q.shape[0]): # normalize rows
        Q[i, :] /= np.linalg.norm(Q[i, :])
    [U, S, V] = np.linalg.svd(Q)
    print(np.linalg.norm(Q)/max(S))
# Out:
# {'v': {'mean': np.float64(0.6939521606663382), 'std': np.float64(0.693952160666338)}, 'rho': {'mean': np.float64(1.0), 'std': np.float64(0.09303344855441158)}}
# 1.3465442748697687
# 1.4193538760678963
# 1.7477122029293577
# 1.6308121165645555

# %%
lib1 = libs[srd.irreps[1]]
for i, term, size in zip(list(range(len(lib1.terms))), lib1.terms, lib1.col_weights):
    print(i, term, size, term.complexity)
print(next(regex_find(lib1.terms, r'∂t ρ\[v_α\]')))
print(next(regex_find(lib1.terms, r'ρ · ∂t ρ\[v_α\]')))
# Out:
# 0 ρ · ∂α ρ 4.6516724277205785 3
# 1 ρ · ∂α ∂β² ρ 11629.181069301445 5
# 2 ρ · ∂t ∂α ρ 197.3786176047413 4
# 3 ρ · ∂t² ∂α ρ 8375.12083942014 5
# 4 ρ · ρ[v_α] 0.6939521606663382 3
# 5 ρ · ∂α ∂β ρ[v_β] 161.4019065964363 5
# 6 ρ · ∂β² ρ[v_α] 161.4019065964363 5
# 7 ρ · ∂t ρ[v_α] 2.739426363122903 4
# 8 ρ · ∂t² ρ[v_α] 116.23866404714565 5
# 9 ρ · ∂β ρ[v_α · v_β] 2.2401040363652687 5
# 10 ρ · ∂α ρ[v_β · v_β] 2.2401040363652687 5
# 11 ρ · ρ[v_α · v_β · v_β] 0.334186265328837 5
# 12 ∂α ρ 4.6516724277205785 2
# 13 ∂α ρ · ∂β² ρ 1081.902818740793 5
# 14 ∂β ρ · ∂α ∂β ρ 1081.902818740793 5
# 15 ∂α ρ · ∂t ρ 18.362813466671575 4
# 16 ∂α ρ · ∂t² ρ 779.166373751174 5
# 17 ∂α ρ · ∂β ρ[v_β] 15.015775973923494 5
# 18 ∂β ρ · ∂β ρ[v_α] 15.015775973923494 5
# 19 ∂β ρ · ∂α ρ[v_β] 15.015775973923494 5
# 20 ∂β ρ · ρ[v_α · v_β] 2.24010403636527 5
# 21 ∂α ρ · ρ[v_β · v_β] 2.24010403636527 5
# 22 ∂α ∂β ρ · ρ[v_β] 161.40190659643633 5
# 23 ∂β² ρ · ρ[v_α] 161.40190659643633 5
# 24 ∂α ∂β² ρ 11629.181069301445 4
# 25 ∂t ρ · ∂t ∂α ρ 779.166373751174 5
# 26 ∂t ρ · ρ[v_α] 2.7394263631229037 4
# 27 ∂t ρ · ∂t ρ[v_α] 10.814083771663652 5
# 28 ∂t ∂α ρ 197.3786176047413 3
# 29 ∂t ∂α ∂β² ρ 493446.5440118532 5
# 30 ∂t² ρ · ρ[v_α] 116.23866404714568 5
# 31 ∂t² ∂α ρ 8375.12083942014 4
# 32 ∂t³ ∂α ρ 355371.062611012 5
# 33 ρ[v_α] 0.6939521606663382 2
# 34 ρ[v_β] · ∂α ρ[v_β] 2.2401040363652696 5
# 35 ρ[v_α] · ∂β ρ[v_β] 2.2401040363652696 5
# 36 ρ[v_α] · ρ[v_β · v_β] 0.334186265328837 5
# 37 ∂α ∂β ρ[v_β] 161.4019065964363 4
# 38 ∂β² ρ[v_α] 161.4019065964363 4
# 39 ∂t ρ[v_α] 2.739426363122903 3
# 40 ∂t ∂β² ρ[v_α] 6848.565907807258 5
# 41 ∂t ∂α ∂β ρ[v_β] 6848.565907807258 5
# 42 ∂t² ρ[v_α] 116.23866404714565 4
# 43 ∂t³ ρ[v_α] 4932.210334744086 5
# 44 ∂β ρ[v_α · v_β] 2.2401040363652687 4
# 45 ∂α ρ[v_β · v_β] 2.2401040363652687 4
# 46 ∂t ∂α ρ[v_β · v_β] 95.05154218377334 5
# 47 ∂t ∂β ρ[v_α · v_β] 95.05154218377334 5
# 48 ρ[v_α · v_β · v_β] 0.334186265328837 4
# 49 ∂t ρ[v_α · v_β · v_β] 1.3192244614619417 5
# (39, ∂t ρ[v_α])
# (7, ρ · ∂t ρ[v_α])

# %%
lib0 = libs[srd.irreps[0]]
for i, term, size in zip(list(range(len(lib0.terms))), lib0.terms, lib0.col_weights):
    print(i, term, size, term.complexity)
print(next(regex_find(lib0.terms, r'∂α² ρ')))
print(next(regex_find(lib0.terms, r'∂t² ρ')))
print(next(regex_find(lib0.terms, r'∂t ∂α ρ\[v_α\]')))
print(next(regex_find(lib0.terms, r'ρ · ∂α² ρ')))
# Out:
# 0 ρ 1.0 1
# 1 ρ · ρ 1.0 2
# 2 ρ · ∂α² ρ 232.58362138602894 4
# 3 ρ · ∂t ρ 3.9475723520948263 3
# 4 ρ · ∂t ∂α² ρ 9868.930880237065 5
# 5 ρ · ∂t² ρ 167.50241678840283 4
# 6 ρ · ∂t³ ρ 7107.421252220241 5
# 7 ρ · ∂α ρ[v_α] 3.228038131928726 4
# 8 ρ · ∂t ∂α ρ[v_α] 136.97131815614514 5
# 9 ρ · ρ[v_α · v_α] 0.4815696012934793 4
# 10 ρ · ∂t ρ[v_α · v_α] 1.9010308436754668 5
# 11 ∂α ρ · ∂α ρ 21.63805637481586 4
# 12 ∂α ρ · ∂t ∂α ρ 918.1406733335787 5
# 13 ∂α ρ · ρ[v_α] 3.228038131928727 4
# 14 ∂α ρ · ∂t ρ[v_α] 12.742914081109667 5
# 15 ∂α² ρ 232.58362138602894 3
# 16 ∂α² ρ · ∂t ρ 918.1406733335789 5
# 17 ∂α² ∂β² ρ 581459.0534650723 5
# 18 ∂t ρ 3.9475723520948263 2
# 19 ∂t ρ · ∂t ρ 15.58332747502348 4
# 20 ∂t ρ · ∂t² ρ 661.2279094229633 5
# 21 ∂t ρ · ∂α ρ[v_α] 12.742914081109669 5
# 22 ∂t ρ · ρ[v_α · v_α] 1.901030843675468 5
# 23 ∂t ∂α ρ · ρ[v_α] 136.97131815614517 5
# 24 ∂t ∂α² ρ 9868.930880237065 4
# 25 ∂t² ρ 167.50241678840283 3
# 26 ∂t² ∂α² ρ 418756.0419710071 5
# 27 ∂t³ ρ 7107.421252220241 4
# 28 ∂t⁴ ρ 301580.3462724092 5
# 29 ρ[v_α] · ρ[v_α] 0.4815696012934793 4
# 30 ρ[v_α] · ∂t ρ[v_α] 1.9010308436754675 5
# 31 ∂α ρ[v_α] 3.228038131928726 3
# 32 ∂α² ∂β ρ[v_β] 8070.095329821814 5
# 33 ∂t ∂α ρ[v_α] 136.97131815614514 4
# 34 ∂t² ∂α ρ[v_α] 5811.933202357282 5
# 35 ρ[v_α · v_α] 0.4815696012934793 3
# 36 ∂α² ρ[v_β · v_β] 112.00520181826343 5
# 37 ∂α ∂β ρ[v_α · v_β] 112.00520181826343 5
# 38 ∂t ρ[v_α · v_α] 1.9010308436754668 4
# 39 ∂t² ρ[v_α · v_α] 80.6640720684853 5
# 40 ∂α ρ[v_α · v_β · v_β] 1.5545250361530634 5
# (15, ∂α² ρ)
# (25, ∂t² ρ)
# (33, ∂t ∂α ρ[v_α])
# (2, ρ · ∂α² ρ)

# %%
col_norms = np.linalg.norm(lib0.Q/lib0.col_weights, axis=0)
print(len(col_norms), lib0.Q.shape)
for term, norm in zip(lib0.terms, col_norms):
    print(term, norm)
# Out:
# 41 (240, 41)
# ρ 3346.449182903165
# ρ · ρ 3441.753805270303
# ρ · ∂α² ρ 900.77236675742
# ρ · ∂t ρ 2535.826704246473
# ρ · ∂t ∂α² ρ 1208.2334348715708
# ρ · ∂t² ρ 3954.6268355778325
# ρ · ∂t³ ρ 8383.318032741287
# ρ · ∂α ρ[v_α] 3101.067068910337
# ρ · ∂t ∂α ρ[v_α] 4836.114707313043
# ρ · ρ[v_α · v_α] 7421.509329054349
# ρ · ∂t ρ[v_α · v_α] 13572.73561289686
# ∂α ρ · ∂α ρ 758.7968123755684
# ∂α ρ · ∂t ∂α ρ 459.2548243337865
# ∂α ρ · ρ[v_α] 1202.4462337289428
# ∂α ρ · ∂t ρ[v_α] 4366.2825576263685
# ∂α² ρ 856.3474038979963
# ∂α² ρ · ∂t ρ 496.11360749939007
# ∂α² ∂β² ρ 1177.3604450345795
# ∂t ρ 2482.105229484212
# ∂t ρ · ∂t ρ 3224.2040974006086
# ∂t ρ · ∂t² ρ 2902.448388654416
# ∂t ρ · ∂α ρ[v_α] 3942.8835730959377
# ∂t ρ · ρ[v_α · v_α] 5273.88995693861
# ∂t ∂α ρ · ρ[v_α] 1923.833269087031
# ∂t ∂α² ρ 1179.550071429917
# ∂t² ρ 3761.643245979102
# ∂t² ∂α² ρ 4414.628513233825
# ∂t³ ρ 8440.75730085795
# ∂t⁴ ρ 45005.851892816325
# ρ[v_α] · ρ[v_α] 6343.591562894588
# ρ[v_α] · ∂t ρ[v_α] 7343.169532936225
# ∂α ρ[v_α] 3035.370173250289
# ∂α² ∂β ρ[v_β] 1442.5460444519817
# ∂t ∂α ρ[v_α] 4600.1189835890045
# ∂t² ∂α ρ[v_α] 10322.184030938075
# ρ[v_α · v_α] 7411.683953011277
# ∂α² ρ[v_β · v_β] 8438.26183442884
# ∂α ∂β ρ[v_α · v_β] 7003.3885656173115
# ∂t ρ[v_α · v_α] 13193.081702503217
# ∂t² ρ[v_α · v_α] 28000.171157162295
# ∂α ρ[v_α · v_β · v_β] 29399.212968314812

# %%
libs1 = libs[srd.irreps[1]]
for term in libs1.terms:
    print(term)
print('***', libs1.terms[40])
# Out:
# ρ · ∂α ρ
# ρ · ∂α ∂β² ρ
# ρ · ∂t ∂α ρ
# ρ · ∂t² ∂α ρ
# ρ · ρ[v_α]
# ρ · ∂α ∂β ρ[v_β]
# ρ · ∂β² ρ[v_α]
# ρ · ∂t ρ[v_α]
# ρ · ∂t² ρ[v_α]
# ρ · ∂β ρ[v_α · v_β]
# ρ · ∂α ρ[v_β · v_β]
# ρ · ρ[v_α · v_β · v_β]
# ∂α ρ
# ∂α ρ · ∂β² ρ
# ∂β ρ · ∂α ∂β ρ
# ∂α ρ · ∂t ρ
# ∂α ρ · ∂t² ρ
# ∂α ρ · ∂β ρ[v_β]
# ∂β ρ · ∂β ρ[v_α]
# ∂β ρ · ∂α ρ[v_β]
# ∂β ρ · ρ[v_α · v_β]
# ∂α ρ · ρ[v_β · v_β]
# ∂α ∂β ρ · ρ[v_β]
# ∂β² ρ · ρ[v_α]
# ∂α ∂β² ρ
# ∂t ρ · ∂t ∂α ρ
# ∂t ρ · ρ[v_α]
# ∂t ρ · ∂t ρ[v_α]
# ∂t ∂α ρ
# ∂t ∂α ∂β² ρ
# ∂t² ρ · ρ[v_α]
# ∂t² ∂α ρ
# ∂t³ ∂α ρ
# ρ[v_α]
# ρ[v_β] · ∂α ρ[v_β]
# ρ[v_α] · ∂β ρ[v_β]
# ρ[v_α] · ρ[v_β · v_β]
# ∂α ∂β ρ[v_β]
# ∂β² ρ[v_α]
# ∂t ρ[v_α]
# ∂t ∂β² ρ[v_α]
# ∂t ∂α ∂β ρ[v_β]
# ∂t² ρ[v_α]
# ∂t³ ρ[v_α]
# ∂β ρ[v_α · v_β]
# ∂α ρ[v_β · v_β]
# ∂t ∂α ρ[v_β · v_β]
# ∂t ∂β ρ[v_α · v_β]
# ρ[v_α · v_β · v_β]
# ∂t ρ[v_α · v_β · v_β]
# *** ∂t ∂β² ρ[v_α]

# %%
lib0 = libs[srd.irreps[0]]
scaler = Scaler(sub_inds=None, char_sizes=lib0.col_weights, row_norms=None, train_fraction=1, unit_rows=True)
init = Initializer(method='combinatorial', start_k=3)
#init = Initializer(method='combinatorial', start_k=9999)
#init = Initializer(method='power', start_k=15)
#res = Residual(residual_type='fixed_column', anchor_col=0)
#res = Residual(residual_type='dominant_balance')
res = Residual(residual_type='matrix_relative')

iterator = ModelIterator(max_k=15, backward_forward=True, max_passes=3)
#iterator = ModelIterator(max_k=len(libs0.terms), backward_forward=True, max_passes=1)

thres = Threshold(threshold_type='jump', gamma=1.5, delta=1e-8, n_terms=None)
#thres = Threshold(threshold_type='information', ic=AIC)

opts = {'scaler': scaler, 'initializer': init, 'residual': res,
        'model_iterator': iterator, 'threshold': thres}

opts['inhomog'] = True
#opts['inhomog_col'] = 1 # ρ²
opts['inhomog_col'] = 15 # ∂α² ρ
#opts['inhomog_col'] = 25 # ∂t² ρ

remove_terms = [34, 2] # ∂t ∂α ρ[v_α], ρ · ∂α² ρ
for term in remove_terms:
    if term in opts['scaler'].sub_inds:
        opts['scaler'].sub_inds.remove(term) 
opts['scaler'].reset_inds(opts['scaler'].sub_inds)

reg_result = sparse_reg_bf(lib0.Q, **opts)
zipped = [(lib0.terms[i], c) for i, c in enumerate(reg_result.xi) if c != 0]
eqn = Equation([e[0] for e in zipped], [e[1] for e in zipped])

print(eqn, "; residual:", reg_result.lambd)
accuracy = compute_accuracy(lib0.Q, reg_result.xi, opts['scaler'])
print(f'(Accuracy = {accuracy:.2e})')
# Out:
# ∂α² ρ + 3.458561807668376e-05 · ∂α² ∂β² ρ + -0.16742039240721238 · ∂t² ρ + 0.16212243877500357 · ∂α ∂β ρ[v_α · v_β] = 0 ; residual: 0.009574382579865549
# (Accuracy = 1.30e-02)

# %%
lib1 = libs[srd.irreps[1]]
scaler = Scaler(sub_inds=None, char_sizes=lib1.col_weights, row_norms=None, train_fraction=1, unit_rows=True)
init = Initializer(method='combinatorial', start_k=3)
#init = Initializer(method='combinatorial', start_k=9999)
#init = Initializer(method='power', start_k=10)
#res = Residual(residual_type='fixed_column', anchor_col=0)
#res = Residual(residual_type='dominant_balance')
res = Residual(residual_type='matrix_relative')

iterator = ModelIterator(max_k=10, backward_forward=True, max_passes=3)
#iterator = ModelIterator(max_k=len(lib1.terms), backward_forward=True, max_passes=1)

thres = Threshold(threshold_type='jump', gamma=1.5, delta=1e-8, n_terms=None)
#thres = Threshold(threshold_type='information', ic=AIC)

opts = {'scaler': scaler, 'initializer': init, 'residual': res,
        'model_iterator': iterator, 'threshold': thres}

opts['inhomog'] = True
opts['inhomog_col'] = 39 # dt rho[v_i]
opts['verbose'] = False

remove_terms = [7] # rho * dt rho[v_i]
for term in remove_terms:
    if term in opts['scaler'].sub_inds:
        opts['scaler'].sub_inds.remove(term) 
opts['scaler'].reset_inds(opts['scaler'].sub_inds)

reg_result = sparse_reg_bf(lib1.Q, **opts)
zipped = [(lib1.terms[i], c) for i, c in enumerate(reg_result.xi) if c != 0]
eqn = Equation([e[0] for e in zipped], [e[1] for e in zipped])

print(eqn, "; residual:", reg_result.lambd)
accuracy = compute_accuracy(lib1.Q, reg_result.xi, opts['scaler'])
print(f'(Accuracy = {accuracy:.2e})')
# Out:
# ρ · ∂α ρ + 3.8045562348903506e-05 · ρ · ∂α ∂β² ρ + 0.16327831650473326 · ∂t ρ[v_α] + 0.16264214754588524 · ∂β ρ[v_α · v_β] = 0 ; residual: 0.00667183579996177
# (Accuracy = 7.32e-03)
